# %% [markdown]
# ### Data science Process CRISP
# ![Annotation%202023-12-23%20010014.png](attachment:Annotation%202023-12-23%20010014.png)

# %% [markdown]
# ## Business Understanding
#  looked at dataset we ask question realted to busniess values
#  using two datasets to do that
#  * **Boston Airbnb**
#  * **Seattle Airbnb**

# %%
# import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Understanding
#   explore data and see what it have from attributes

# %%
# import data from csv files 
boston_cal = pd.read_csv('Bostoncalendar.csv')
boston_listing = pd.read_csv('Bostonlistings.csv')
seattle_cal =pd.read_csv('Seattlecalendar.csv')
seattle_listing = pd.read_csv('Seattlelistings.csv')

# %% [markdown]
# ##  Boston Calender

# %%
boston_cal.head()
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN
# 2    12147973  2017-09-03         f   NaN
# 3    12147973  2017-09-02         f   NaN
# 4    12147973  2017-09-01         f   NaN

# %%
# availability categories is eith t or f , t for available and f not avaliables 
boston_cal['available'].value_counts()
# Out:
# available
# f    665853
# t    643037
# Name: count, dtype: int64

# %%
# only available have prices 
boston_cal[boston_cal['available']=='t']
# Out:
#          listing_id        date available   price
# 365         3075044  2017-08-22         t  $65.00
# 366         3075044  2017-08-21         t  $65.00
# 367         3075044  2017-08-20         t  $65.00
# 368         3075044  2017-08-19         t  $75.00
# 369         3075044  2017-08-18         t  $75.00
# ...             ...         ...       ...     ...
# 1308875    14504422  2016-09-20         t  $62.00
# 1308876    14504422  2016-09-19         t  $62.00
# 1308877    14504422  2016-09-18         t  $62.00
# 1308878    14504422  2016-09-17         t  $62.00
# 1308879    14504422  2016-09-16         t  $62.00
#
# [643037 rows x 4 columns]

# %%
# new data set that have only available 
boston_cal_t = boston_cal[boston_cal['available']=='t']

# %%
boston_cal_t
# Out:
#          listing_id        date available   price
# 365         3075044  2017-08-22         t  $65.00
# 366         3075044  2017-08-21         t  $65.00
# 367         3075044  2017-08-20         t  $65.00
# 368         3075044  2017-08-19         t  $75.00
# 369         3075044  2017-08-18         t  $75.00
# ...             ...         ...       ...     ...
# 1308875    14504422  2016-09-20         t  $62.00
# 1308876    14504422  2016-09-19         t  $62.00
# 1308877    14504422  2016-09-18         t  $62.00
# 1308878    14504422  2016-09-17         t  $62.00
# 1308879    14504422  2016-09-16         t  $62.00
#
# [643037 rows x 4 columns]

# %% [markdown]
# ## Boston Listing

# %%
boston_listing
# Out:
#             id                            listing_url       scrape_id  \
# 0     12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1      3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2         6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3      1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4      7651065   https://www.airbnb.com/rooms/7651065  20160906204935
# ...        ...                                    ...             ...
# 3580   8373729   https://www.airbnb.com/rooms/8373729  20160906204935
# 3581  14844274  https://www.airbnb.com/rooms/14844274  20160906204935
# 3582  14585486  https://www.airbnb.com/rooms/14585486  20160906204935
# 3583  14603878  https://www.airbnb.com/rooms/14603878  20160906204935
# 3584  14504422  https://www.airbnb.com/rooms/14504422  20160906204935
#
#      last_scraped                                           name  \
# ...

# %%
# there are 95 columns in this list so we need only few columns related to business understanding questions
boston_listing.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
# ...

# %% [markdown]
# ### we will choose some attributes that related to prices
#  * 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds','price'

# %%
#seattle listing and boston listing
seattle_list = seattle_listing[['id', 'property_type', 'room_type', 'accommodates',
       'bathrooms', 'bedrooms', 'beds','price']]
boston_list = boston_listing[['id', 'property_type', 'room_type', 'accommodates',
       'bathrooms', 'bedrooms', 'beds','price']]

# %%
seattle_list
# Out:
#             id property_type        room_type  accommodates  bathrooms  \
# 0       241032     Apartment  Entire home/apt             4        1.0
# 1       953595     Apartment  Entire home/apt             4        1.0
# 2      3308979         House  Entire home/apt            11        4.5
# 3      7421966     Apartment  Entire home/apt             3        1.0
# 4       278830         House  Entire home/apt             6        2.0
# ...        ...           ...              ...           ...        ...
# 3813   8101950         House  Entire home/apt             6        2.0
# 3814   8902327     Apartment  Entire home/apt             4        1.0
# 3815  10267360         House  Entire home/apt             2        1.0
# 3816   9604740   Condominium  Entire home/apt             2        1.0
# 3817  10208623     Apartment  Entire home/apt             3        1.5
#
#       bedrooms  beds    price
# 0          1.0   1.0   $85.00
# 1          1.0   1.0  $150.00
# ...
